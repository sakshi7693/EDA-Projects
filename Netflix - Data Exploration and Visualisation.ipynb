# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Sakshi Rathore\\Downloads\\Scaler\\Project\\netflix.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include='all')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8804           4528                7692
# top         s1  Movie  15-Aug  Rajiv Chilaka  David Attenborough
# freq         1   6131       2             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %%
df.describe(include='object')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8804           4528                7692
# top         s1  Movie  15-Aug  Rajiv Chilaka  David Attenborough
# freq         1   6131       2             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#check inconsistancy
df['type'].nunique()
print(df['type'].unique())
# Out:
# ['Movie' 'TV Show']

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
m_df=df[df['type']=='Movie']
tv_df=df[df['type']=='TV Show']

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['director'].nunique()
# Out:
# 4528

# %%
#count for director movies
m_df['director'].str.split(', ').explode().nunique()
# Out:
# 4777

# %%
#count for director tv shows
tv_df['director'].str.split(', ').explode().nunique()
# Out:
# 299

# %%
#top director
m_df['director'].str.split(', ').explode().value_counts()
# Out:
# director
# Rajiv Chilaka        22
# Jan Suter            21
# Raúl Campos          19
# Suhas Kadav          16
# Marcus Raboy         15
#                      ..
# Vrinda Samartha       1
# Nicholaus Goossen     1
# Stig Bergqvist        1
# Paul Demeyer          1
# Mozez Singh           1
# Name: count, Length: 4777, dtype: int64

# %%
tv_df['director'].str.split(', ').explode().value_counts()
# Out:
# director
# Alastair Fothergill      3
# Ken Burns                3
# Jung-ah Im               2
# Gautham Vasudev Menon    2
# Iginio Straffi           2
#                         ..
# Jesse Vile               1
# Ellena Wood              1
# Picky Talarico           1
# Pedro Waddington         1
# Michael Cumming          1
# Name: count, Length: 299, dtype: int64

# %%
#total country for movies
m_df['country'].str.split(', ').explode().nunique()
# Out:
# 122

# %%
m_df['country'].str.split(', ').explode().value_counts()
# Out:
# country
# United States     2751
# India              962
# United Kingdom     532
# Canada             319
# France             303
#                   ...
# Bermuda              1
# Angola               1
# Armenia              1
# Mongolia             1
# Montenegro           1
# Name: count, Length: 122, dtype: int64

# %%
#total country for tv shows
tv_df['country'].str.split(', ').explode().nunique()
# Out:
# 66

# %%
tv_df['country'].str.split(', ').explode().value_counts()
# Out:
# country
# United States           938
# United Kingdom          272
# Japan                   199
# South Korea             170
# Canada                  126
#                        ...
# Malta                     1
# Belarus                   1
# United Arab Emirates      1
# Uruguay                   1
# Switzerland               1
# Name: count, Length: 66, dtype: int64

# %%
m_df['listed_in'].str.split(', ').explode().nunique()
# Out:
# 20

# %%
m_df['listed_in'].str.split(', ').explode().unique()
# Out:
# array(['Documentaries', 'Children & Family Movies', 'Dramas',
#        'Independent Movies', 'International Movies', 'Comedies',
#        'Thrillers', 'Romantic Movies', 'Music & Musicals',
#        'Horror Movies', 'Sci-Fi & Fantasy', 'Action & Adventure',
#        'Classic Movies', 'Anime Features', 'Sports Movies', 'Cult Movies',
#        'Faith & Spirituality', 'LGBTQ Movies', 'Stand-Up Comedy',
#        'Movies'], dtype=object)

# %%
m_df['listed_in'].str.split(', ').explode().value_counts()
# Out:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# Documentaries                869
# Action & Adventure           859
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Thrillers                    577
# Music & Musicals             375
# Horror Movies                357
# Stand-Up Comedy              343
# Sci-Fi & Fantasy             243
# Sports Movies                219
# Classic Movies               116
# LGBTQ Movies                 102
# Anime Features                71
# Cult Movies                   71
# Faith & Spirituality          65
# Movies                        57
# Name: count, dtype: int64

# %%
tv_df['listed_in'].str.split(', ').explode().unique()
# Out:
# array(['International TV Shows', 'TV Dramas', 'TV Mysteries',
#        'Crime TV Shows', 'TV Action & Adventure', 'Docuseries',
#        'Reality TV', 'Romantic TV Shows', 'TV Comedies', 'TV Horror',
#        'British TV Shows', 'Spanish-Language TV Shows', 'TV Thrillers',
#        "Kids' TV", 'TV Sci-Fi & Fantasy', 'Anime Series',
#        'Korean TV Shows', 'Science & Nature TV', 'Teen TV Shows',
#        'TV Shows', 'Stand-Up Comedy & Talk Shows', 'Classic & Cult TV'],
#       dtype=object)

# %%
tv_df['listed_in'].str.split(', ').explode().nunique()
# Out:
# 22

# %%
tv_df['listed_in'].str.split(', ').explode().value_counts()
# Out:
# listed_in
# International TV Shows          1351
# TV Dramas                        763
# TV Comedies                      581
# Crime TV Shows                   470
# Kids' TV                         451
# Docuseries                       395
# Romantic TV Shows                370
# Reality TV                       255
# British TV Shows                 253
# Anime Series                     176
# Spanish-Language TV Shows        174
# TV Action & Adventure            168
# Korean TV Shows                  151
# TV Mysteries                      98
# Science & Nature TV               92
# TV Sci-Fi & Fantasy               84
# TV Horror                         75
# Teen TV Shows                     69
# TV Thrillers                      57
# Stand-Up Comedy & Talk Shows      56
# Classic & Cult TV                 28
# TV Shows                          16
# Name: count, dtype: int64

# %%
m_df['release_year'].agg(['min','max'])
# Out:
# min    1942
# max    2021
# Name: release_year, dtype: int64

# %%
 tv_df['release_year'].agg(['min','max'])
# Out:
# min    1925
# max    2021
# Name: release_year, dtype: int64

# %%
m_df['date_added']=pd.to_datetime(m_df['date_added'])
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\428203804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_df['date_added']=pd.to_datetime(m_df['date_added'])

# %%
 m_df['date_added'].agg(['min','max'])
# Out:
# min   2008-01-01
# max   2021-09-25
# Name: date_added, dtype: datetime64[ns]

# %%
tv_df['date_added'] = pd.to_datetime(tv_df['date_added'], infer_datetime_format=True, errors='coerce')
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\2886632295.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   tv_df['date_added'] = pd.to_datetime(tv_df['date_added'], infer_datetime_format=True, errors='coerce')
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\2886632295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_df['date_added'] = pd.to_datetime(tv_df['date_added'], infer_datetime_format=True, errors='coerce')

# %%
 tv_df['date_added'].agg(['min','max'])
# Out:
# min   2008-02-04
# max   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
#creating mdir_df with unnested values of movies
mdir_df=m_df.loc[:,['show_id','director']]                   
mdir_df['director']=mdir_df['director'].str.split(', ')
mdir_df=mdir_df.explode('director')

# %%
mdir_df.head()
# Out:
#   show_id         director
# 0      s1  Kirsten Johnson
# 6      s7    Robert Cullen
# 6      s7   José Luis Ucha
# 7      s8     Haile Gerima
# 9     s10   Theodore Melfi

# %%
#creating tvdir_df with unnested values of tv shows
tvdir_df=tv_df.loc[:,['show_id','director']]                   
tvdir_df['director']=tvdir_df['director'].str.split(', ')
tvdir_df=tvdir_df.explode('director')

# %%
tvdir_df.head()
# Out:
#   show_id         director
# 1      s2              NaN
# 2      s3  Julien Leclercq
# 3      s4              NaN
# 4      s5              NaN
# 5      s6    Mike Flanagan

# %%
#creating mcast_df with unnested values of movies
mcast_df=m_df.loc[:,['show_id','cast']]                
mcast_df['cast']=mcast_df['cast'].str.split(', ')
mcast_df=mcast_df.explode('cast')

# %%
mcast_df.head()
# Out:
#   show_id             cast
# 0      s1              NaN
# 6      s7  Vanessa Hudgens
# 6      s7     Kimiko Glenn
# 6      s7    James Marsden
# 6      s7     Sofia Carson

# %%
#creating tvcast_data with unnested values of tv shows
tvcast_df=tv_df.loc[:,['show_id','cast']]               
tvcast_df['cast']=tvcast_df['cast'].str.split(', ')
tvcast_df=tvcast_df.explode('cast')

# %%
tvcast_df.head()
# Out:
#   show_id              cast
# 1      s2        Ama Qamata
# 1      s2       Khosi Ngema
# 1      s2     Gail Mabalane
# 1      s2    Thabang Molaba
# 1      s2  Dillon Windvogel

# %%
#creating mcountry_df with unnested values of movies
mcountry_df=m_df.loc[:,['show_id','country']]              
mcountry_df['country']=mcountry_df['country'].str.split(', ')
mcountry_df=mcountry_df.explode('country')

# %%
mcountry_df.head()
# Out:
#   show_id        country
# 0      s1  United States
# 6      s7            NaN
# 7      s8  United States
# 7      s8          Ghana
# 7      s8   Burkina Faso

# %%
#creating mcountry_df with unnested values of movies
tvcountry_df=tv_df.loc[:,['show_id','country']]              
tvcountry_df['country']=tvcountry_df['country'].str.split(', ')
tvcountry_df=tvcountry_df.explode('country')

# %%
tvcountry_df.head()
# Out:
#   show_id       country
# 1      s2  South Africa
# 2      s3           NaN
# 3      s4           NaN
# 4      s5         India
# 5      s6           NaN

# %%
#creating mlisted_data with unnested values of movies 
mlisted_df=m_df.loc[:,['show_id','listed_in']]                
mlisted_df['listed_in']=mlisted_df['listed_in'].str.split(', ')
mlisted_df=mlisted_df.explode('listed_in')

# %%
mlisted_df.head()
# Out:
#   show_id                 listed_in
# 0      s1             Documentaries
# 6      s7  Children & Family Movies
# 7      s8                    Dramas
# 7      s8        Independent Movies
# 7      s8      International Movies

# %%
#creating tvlisted_data with unnested values
tvlisted_df=tv_df.loc[:,['show_id','listed_in']]                 
tvlisted_df['listed_in']=tvlisted_df['listed_in'].str.split(', ')
tvlisted_df=tvlisted_df.explode('listed_in')

# %%
tvlisted_df.head()
# Out:
#   show_id               listed_in
# 1      s2  International TV Shows
# 1      s2               TV Dramas
# 1      s2            TV Mysteries
# 2      s3          Crime TV Shows
# 2      s3  International TV Shows

# %%
m_df.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country date_added  \
# ...

# %%
tv_df.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country date_added  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa 2021-09-24
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN 2021-09-24
# 3                                                NaN           NaN 2021-09-24
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN 2021-09-24
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# ...

# %%
#converting movie duration to number of minutes
m_df['duration']=m_df['duration'].str.split()                            
m_df['duration']=m_df['duration'].str[0]

#filling missing values as median
m_df['duration']=m_df['duration'].fillna(m_df['duration'].median())     
m_df['duration']=m_df['duration'].astype(int)
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\3406697464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_df['duration']=m_df['duration'].str.split()
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\3406697464.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_df['duration']=m_df['duration'].str[0]
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\3406697464.py:6: SettingWithCopyWarning:
# ...

# %%
 m_df.rename(columns={'duration':'duration(min)'},inplace=True)
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\55214251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_df.rename(columns={'duration':'duration(min)'},inplace=True)

# %%
m_df.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country date_added  \
# ...

# %%
#converting tv shows duration to number of minutes
tv_df['duration']=tv_df['duration'].str.split()                            
tv_df['duration']=tv_df['duration'].str[0]

#filling missing values as median
tv_df['duration']=tv_df['duration'].fillna(tv_df['duration'].median())    
tv_df['duration']=tv_df['duration'].astype(int)
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\98553146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_df['duration']=tv_df['duration'].str.split()
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\98553146.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_df['duration']=tv_df['duration'].str[0]
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\98553146.py:6: SettingWithCopyWarning:
# ...

# %%
tv_df.rename(columns={'duration':'duration(no. of session)'},inplace=True)
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\3397726483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_df.rename(columns={'duration':'duration(no. of session)'},inplace=True)

# %%
tv_df.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country date_added  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa 2021-09-24
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN 2021-09-24
# 3                                                NaN           NaN 2021-09-24
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN 2021-09-24
#
#    release_year rating  duration(no. of session)  \
# 1          2021  TV-MA                         2
# ...

# %%
df['date_added']=pd.to_datetime(df['date_added'], infer_datetime_format=True, errors='coerce')
df['year_diff']=(df['date_added'].dt.year) - (df['release_year'])
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\1476630546.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['date_added']=pd.to_datetime(df['date_added'], infer_datetime_format=True, errors='coerce')

# %%
#directors and cast of movies who prefer to work together 
merge_df=mdir_df.merge(mcast_df,on='show_id')               
merge_df.groupby(['director','cast']).agg('count').sort_values(by='show_id',ascending=False).head(20)
# Out:
#                                       show_id
# director          cast
# Rajiv Chilaka     Rajesh Kava              19
#                   Julie Tejwani            19
#                   Jigna Bhardwaj           18
#                   Rupa Bhimani             18
#                   Vatsal Dubey             16
#                   Swapnil                  13
#                   Mousam                   13
# Suhas Kadav       Saurav Chakraborty        8
# Toshiya Shinohara Koji Tsujitani            7
#                   Satsuki Yukino            7
# S.S. Rajamouli    Rana Daggubati            7
# Toshiya Shinohara Houko Kuwashima           7
# Yılmaz Erdoğan    Yılmaz Erdoğan            7
# S.S. Rajamouli    Ramya Krishnan            7
#                   Prabhas                   7
#                   Nassar                    7
#                   Tamannaah Bhatia          7
#                   Sathyaraj                 7
# Toshiya Shinohara Kumiko Watanabe           7
# ...

# %%
merge_df=tvdir_df.merge(tvcast_df,on='show_id')
merge_df.groupby(['director','cast']).agg('count').sort_values(by='show_id',ascending=False).head(10)
# Out:
#                                              show_id
# director              cast
# Alastair Fothergill   David Attenborough           3
# Gautham Vasudev Menon Prakash Raj                  2
# Stan Lathan           Dave Chappelle               2
# Shin Won-ho           Sung Dong-il                 2
#                       Lee Il-hwa                   2
# Gautham Vasudev Menon Anjali                       2
#                       Gautham Vasudev Menon        2
# Onur Ünlü             Ahmet Mümtaz Taylan          1
#                       Ali Atay                     1
#                       Cengiz Bozkurt               1

# %%
d1=df['type'].value_counts()
plt.pie(d1,labels=d1.index,autopct='%.0f%%')
plt.title('Movies and TV Shows Contribution')
# Out:
# Text(0.5, 1.0, 'Movies and TV Shows Contribution')

# %%
# Extracting the top 5 most popular directors
top_directors = mdir_df['director'].value_counts().index[:5]

# Creating a count plot for the top directors
sns.countplot(data=mdir_df[mdir_df['director'].isin(top_directors)], x='director')
plt.title('Most Popular Directors (Movies)')
plt.show()

# %%
top_directors = tvdir_df['director'].value_counts().index[:5]

# Creating a count plot for the top directors
sns.countplot(data=tvdir_df[tvdir_df['director'].isin(top_directors)], x='director')
plt.title('Most Popular Directors (Tv Shows)')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=mcountry_df[mcountry_df['country'].isin(mcountry_df['country'].value_counts().index[:5])],x='country')     
plt.xticks(rotation = 45)
plt.title('Countries with Maximum Movies')
plt.show()

# %%
sns.countplot(data=tvcountry_df[tvcountry_df['country'].isin(tvcountry_df['country'].value_counts().index[:5])],x='country')     
plt.xticks(rotation = 45)
plt.title('Countries with Maximum Tv Shows')
plt.show()

# %%
plt.hist(df['date_added'].dt.month)
plt.xlabel('month')
plt.ylabel('movies')
plt.title('Number of Movies Added to Netflix by Month')
# Out:
# Text(0.5, 1.0, 'Number of Movies Added to Netflix by Month')

# %%
sns.distplot(df['year_diff'])
# Out:
# C:\Users\Sakshi Rathore\AppData\Local\Temp\ipykernel_9644\683124051.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['year_diff'])
# <Axes: xlabel='year_diff', ylabel='Density'>

# %%
sns.countplot(data=mlisted_df[mlisted_df['listed_in'].isin(mlisted_df['listed_in'].value_counts().index[:5])],x='listed_in')    
plt.xticks(rotation=90)
plt.title('Most Popular Movies Categories')
# Out:
# Text(0.5, 1.0, 'Most Popular Movies Categories')

# %%
sns.countplot(data=tvlisted_df[tvlisted_df['listed_in'].isin(tvlisted_df['listed_in'].value_counts().index[:5])],x='listed_in')    
plt.xticks(rotation=90)
plt.title('Most Popular Tv Show Categories')
# Out:
# Text(0.5, 1.0, 'Most Popular Tv Show Categories')

# %%
usm_df=mcountry_df[mcountry_df['country']=='United States'].merge(mlisted_df,on='show_id')                     
sns.countplot(data=usm_df[usm_df['listed_in'].isin(usm_df['listed_in'].value_counts().index[:5])],x='listed_in')
plt.xticks(rotation=90)
plt.title('Categories with max number of movies in US')
# Out:
# Text(0.5, 1.0, 'Categories with max number of movies in US')

# %%
ustv_df=tvcountry_df[tvcountry_df['country']=='United States'].merge(tvlisted_df,on='show_id')                     
sns.countplot(data=ustv_df[ustv_df['listed_in'].isin(ustv_df['listed_in'].value_counts().index[:5])],x='listed_in')
plt.xticks(rotation=90)
plt.title('Categories with max number of Tv Show in US')
# Out:
# Text(0.5, 1.0, 'Categories with max number of Tv Show in US')

# %%
usm_df=mcountry_df[mcountry_df['country']=='United States'].merge(mcast_df,on='show_id')                     
sns.countplot(data=usm_df[usm_df['cast'].isin(usm_df['cast'].value_counts().index[:5])],x='cast')
plt.xticks(rotation=90)
plt.title('Cast with max number of movies in US')
# Out:
# Text(0.5, 1.0, 'Cast with max number of movies in US')

# %%
ustv_df=tvcountry_df[tvcountry_df['country']=='United States'].merge(tvcast_df,on='show_id')                     
sns.countplot(data=ustv_df[ustv_df['cast'].isin(ustv_df['cast'].value_counts().index[:5])],x='cast')
plt.xticks(rotation=90)
plt.title('Cast with max number of TV shows in US')
# Out:
# Text(0.5, 1.0, 'Cast with max number of TV shows in US')

# %%
#Movies and Tv shows and release_year
#sns.boxplot(df=df,y='release_year',x='type')               
#plt.title("Boxplot of Release Year")
#plt.xlabel("Release Year")
#plt.show()

# Check and handle missing values
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')

# Check 'type' values
valid_types = ['Movie', 'TV Show']
df = df[df['type'].isin(valid_types)]

# Create boxplot
sns.boxplot(data=df, y='release_year', x='type')
plt.title("Boxplot of Release Year")
plt.xlabel("Release Year")
plt.show()

# %%
#duration of movies
sns.boxplot(m_df['duration(min)'])                
plt.title("Boxplot of Duration(movies)")
plt.ylabel("Duration (in minutes)")
plt.show()

# %%
dummy=mlisted_df.merge(m_df, on='show_id')
dummy=dummy[dummy['duration(min)']>=15]['listed_in_x'].value_counts()
plt.pie(dummy,labels=dummy.index,autopct='%.0f%%')
plt.title('Categories of most successful Tv shows')
# Out:
# Text(0.5, 1.0, 'Categories of most successful Tv shows')

# %%
#duration of tv shows
sns.boxplot(tv_df['duration(no. of session)'])                
plt.title("Boxplot of Duration(tv show)")
plt.ylabel("Duration (in minutes)")
plt.show()

# %%
dummy=tvlisted_df.merge(tv_df, on='show_id')
dummy=dummy[dummy['duration(no. of session)']>=15]['listed_in_x'].value_counts()
plt.pie(dummy,labels=dummy.index,autopct='%.0f%%')
plt.title('Categories of most successful Tv shows')
# Out:
# Text(0.5, 1.0, 'Categories of most successful Tv shows')

# %%
#top 5 movies directors
dir_rel['release_year'] = pd.to_numeric(dir_rel['release_year'], errors='coerce')

# Check 'director' values
valid_directors = dir_rel['director'].value_counts().index[:5]
dir_rel = dir_rel[dir_rel['director'].isin(valid_directors)]

# Create boxplot
sns.boxplot(data=dir_rel, x='director', y='release_year')
plt.xticks(rotation=90)
plt.title('Timeperiod for the top 5 movie directors')
plt.show()

# %%
#top 5 tv shows director
dir_rel=tvdir_df.merge(tv_df, on='show_id')               
dir_rel.drop(columns=['director_y'],inplace=True)
dir_rel.rename(columns={'director_x':'director'},inplace=True)
sns.boxplot(data=dir_rel[dir_rel['director'].isin(dir_rel['director'].value_counts().index[:5])],x='director',y='release_year')
plt.xticks(rotation=90)
plt.title('Timeperiod for the top 5 tv show directors')
plt.show()

# %%
#correlation 
#Pairplot
m_df['date_added']=m_df['date_added'].dt.year

# %%
m_df.corr(numeric_only=True)
# Out:
#                date_added  release_year  duration(min)
# date_added       1.000000      0.039285       0.124398
# release_year     0.039285      1.000000      -0.206282
# duration(min)    0.124398     -0.206282       1.000000

# %%
sns.pairplot(m_df)

# %%
tv_df['date_added']=tv_df['date_added'].dt.year

# %%
tv_df.corr(numeric_only = True)
# Out:
#                           date_added  release_year  duration(no. of session)
# date_added                  1.000000      0.388184                  0.106543
# release_year                0.388184      1.000000                 -0.090194
# duration(no. of session)    0.106543     -0.090194                  1.000000

# %%
sns.pairplot(tv_df)

# %%
#Heatmap for movies
sns.heatmap(data=m_df.corr(numeric_only=True),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
#heatmap for tvshow
sns.heatmap(data=tv_df.corr(numeric_only=True),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
#checking for missing values
m_df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director         188
# cast             475
# country          440
# date_added         0
# release_year       0
# rating             2
# duration(min)      0
# listed_in          0
# description        0
# dtype: int64

# %%
tv_df.isnull().sum()
# Out:
# show_id                        0
# type                           0
# title                          0
# director                    2446
# cast                         350
# country                      391
# date_added                    98
# release_year                   0
# rating                         2
# duration(no. of session)       0
# listed_in                      0
# description                    0
# dtype: int64

# %%
 m_df.dropna(subset=['rating'],inplace=True)

# %%
 tv_df.dropna(subset=['rating'],inplace=True)

# %%
 m_df.dropna(subset=['date_added'],inplace=True)

# %%
 tv_df.dropna(subset=['date_added'],inplace=True)

# %%
# Filling misssing values for m_data and tv_data to unknown
m_df.fillna('unknown',inplace=True)

# %%
tv_df.fillna('unknown',inplace=True)

# %%
m_df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration(min)    0
# listed_in        0
# description      0
# dtype: int64

# %%
tv_df.isnull().sum()
# Out:
# show_id                     0
# type                        0
# title                       0
# director                    0
# cast                        0
# country                     0
# date_added                  0
# release_year                0
# rating                      0
# duration(no. of session)    0
# listed_in                   0
# description                 0
# dtype: int64
